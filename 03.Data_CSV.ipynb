# %%
print(getwd())
# Out:
# [1] "/home/angicia/Workspace/Machine-Learning-using-R"

# %%
data <- read.csv("Sample.csv")

# %%
print(data)
# Out:
#                                Region                          Country
# 1               Australia and Oceania                           Tuvalu
# 2   Central America and the Caribbean                          Grenada
# 3                              Europe                           Russia
# 4                  Sub-Saharan Africa            Sao Tome and Principe
# 5                  Sub-Saharan Africa                           Rwanda
# 6               Australia and Oceania                  Solomon Islands
# 7                  Sub-Saharan Africa                           Angola
# 8                  Sub-Saharan Africa                     Burkina Faso
# 9                  Sub-Saharan Africa            Republic of the Congo
# 10                 Sub-Saharan Africa                          Senegal
# 11                               Asia                       Kyrgyzstan
# 12                 Sub-Saharan Africa                       Cape Verde
# ...

# %%
print(is.data.frame(data))
# Out:
# [1] TRUE

# %%
print(ncol(data))
# Out:
# [1] 14

# %%
x <- data$Region

# %%
x
# Out:
#   [1] Australia and Oceania             Central America and the Caribbean
#   [3] Europe                            Sub-Saharan Africa
#   [5] Sub-Saharan Africa                Australia and Oceania
#   [7] Sub-Saharan Africa                Sub-Saharan Africa
#   [9] Sub-Saharan Africa                Sub-Saharan Africa
#  [11] Asia                              Sub-Saharan Africa
#  [13] Asia                              Central America and the Caribbean
#  [15] Asia                              Europe
#  [17] Asia                              Sub-Saharan Africa
#  [19] Asia                              Australia and Oceania
#  [21] Europe                            Europe
#  [23] Central America and the Caribbean Australia and Oceania
#  [25] Europe                            Europe
#  [27] Australia and Oceania             Sub-Saharan Africa
#  [29] Europe                            Sub-Saharan Africa
#  [31] Europe                            Sub-Saharan Africa
# ...

# %%
data <- read.csv("insurance_sample.csv")

# %%
data
# Out:
#       policyID statecode county          eq_site_limit hu_site_limit
# 1     119736   FL        CLAY COUNTY      498960.0       498960.00
# 2     448094   FL        CLAY COUNTY     1322376.3      1322376.30
# 3     206893   FL        CLAY COUNTY      190724.4       190724.40
# 4     333743   FL        CLAY COUNTY           0.0        79520.76
# 5     172534   FL        CLAY COUNTY           0.0       254281.50
# 6     785275   FL        CLAY COUNTY           0.0       515035.62
# 7     995932   FL        CLAY COUNTY           0.0     19260000.00
# 8     223488   FL        CLAY COUNTY      328500.0       328500.00
# 9     433512   FL        CLAY COUNTY      315000.0       315000.00
# 10    142071   FL        CLAY COUNTY      705600.0       705600.00
# 11    253816   FL        CLAY COUNTY      831498.3       831498.30
# 12    894922   FL        CLAY COUNTY           0.0        24059.09
# 13    422834   FL        CLAY COUNTY           0.0        48115.94
# ...

# %%
print(is.data.frame(data))
# Out:
# [1] TRUE

# %%
print(ncol(data))
# Out:
# [1] 18

# %%
print(nrow(data))
# Out:
# [1] 36634

# %%
x <- max(data$eq_site_limit)

# %%
x
# Out:
# [1] 2.16e+09

# %%
x <-data$eq_site_limit

# %%
retval <- subset(data, x == max(x))

# %%
retval
# Out:
#       policyID statecode county        eq_site_limit hu_site_limit
# 14103 340585   FL        ORANGE COUNTY 2.16e+09      2.16e+09
#       fl_site_limit fr_site_limit tiv_2011 tiv_2012  eq_site_deductible
# 14103 2.16e+09      2.16e+09      2.16e+09 1.701e+09 0
#       hu_site_deductible fl_site_deductible fr_site_deductible point_latitude
# 14103 0                  0                  0                  28.39462
#       point_longitude line       construction point_granularity
# 14103 -81.57272       Commercial Steel Frame  4

# %%
retval <- subset( data, county == "ORANGE COUNTY")

# %%
retval
# Out:
#       policyID statecode county        eq_site_limit hu_site_limit
# 10703 817319   FL        ORANGE COUNTY        0.0       90000.00
# 10706 930249   FL        ORANGE COUNTY  7994803.5     7994803.50
# 10707 911805   FL        ORANGE COUNTY  2122582.5     2122582.50
# 10708 911763   FL        ORANGE COUNTY  1395000.0     1395000.00
# 10710 556390   FL        ORANGE COUNTY    77400.0       77400.00
# 10711 425483   FL        ORANGE COUNTY    22500.0       22500.00
# 10712 318253   FL        ORANGE COUNTY        0.0      321781.68
# 10713 388452   FL        ORANGE COUNTY        0.0       20342.52
# 10714 915061   FL        ORANGE COUNTY        0.0      537227.46
# 10715 989895   FL        ORANGE COUNTY        0.0     2195142.84
# 10716 125162   FL        ORANGE COUNTY        0.0    59490000.00
# 10717 476358   FL        ORANGE COUNTY   300994.2      300994.20
# 10718 998680   FL        ORANGE COUNTY   530185.5      530185.50
# ...

# %%
info <- subset(data, eq_site_limit = 0 & county == "ORANGE COUNTY")

# %%
info
# Out:
#       policyID statecode county          eq_site_limit hu_site_limit
# 1     119736   FL        CLAY COUNTY      498960.0       498960.00
# 2     448094   FL        CLAY COUNTY     1322376.3      1322376.30
# 3     206893   FL        CLAY COUNTY      190724.4       190724.40
# 4     333743   FL        CLAY COUNTY           0.0        79520.76
# 5     172534   FL        CLAY COUNTY           0.0       254281.50
# 6     785275   FL        CLAY COUNTY           0.0       515035.62
# 7     995932   FL        CLAY COUNTY           0.0     19260000.00
# 8     223488   FL        CLAY COUNTY      328500.0       328500.00
# 9     433512   FL        CLAY COUNTY      315000.0       315000.00
# 10    142071   FL        CLAY COUNTY      705600.0       705600.00
# 11    253816   FL        CLAY COUNTY      831498.3       831498.30
# 12    894922   FL        CLAY COUNTY           0.0        24059.09
# 13    422834   FL        CLAY COUNTY           0.0        48115.94
# ...

# %%
retval <- subset(data, eq_site_limit>hu_site_limit)

# %%
retval
# Out:
#       policyID statecode county              eq_site_limit hu_site_limit
# 1751  808985   FL        VOLUSIA COUNTY        225652.5     225000
# 1865  830263   FL        VOLUSIA COUNTY       3592673.1          0
# 2123  578379   FL        FLAGLER COUNTY       3903302.7          0
# 2528  711199   FL        VOLUSIA COUNTY       5541439.5          0
# 3993  934958   FL        DUVAL COUNTY         1562177.7          0
# 3994  992407   FL        DUVAL COUNTY          324000.0          0
# 4162  783331   FL        DUVAL COUNTY          243000.0          0
# 4277  172518   FL        DUVAL COUNTY         7038737.1          0
# 4622  489799   FL        DUVAL COUNTY         3324883.5          0
# 4793  651400   FL        ST  JOHNS COUNTY     1482427.8          0
# 4794  727059   FL        ST  JOHNS COUNTY      390150.0          0
# 8555  287597   FL        OKALOOSA COUNTY      3161792.7          0
# 9061  628535   FL        OKALOOSA COUNTY      4167546.3          0
# ...

# %%
write.csv(retval,"output.csv")

# %%
newdata <- read.csv("output.csv")

# %%
print(newdata)
# Out:
#        X policyID statecode              county eq_site_limit hu_site_limit
# 1   1751   808985        FL      VOLUSIA COUNTY      225652.5        225000
# 2   1865   830263        FL      VOLUSIA COUNTY     3592673.1             0
# 3   2123   578379        FL      FLAGLER COUNTY     3903302.7             0
# 4   2528   711199        FL      VOLUSIA COUNTY     5541439.5             0
# 5   3993   934958        FL        DUVAL COUNTY     1562177.7             0
# 6   3994   992407        FL        DUVAL COUNTY      324000.0             0
# 7   4162   783331        FL        DUVAL COUNTY      243000.0             0
# 8   4277   172518        FL        DUVAL COUNTY     7038737.1             0
# 9   4622   489799        FL        DUVAL COUNTY     3324883.5             0
# 10  4793   651400        FL    ST  JOHNS COUNTY     1482427.8             0
# 11  4794   727059        FL    ST  JOHNS COUNTY      390150.0             0
# ...
