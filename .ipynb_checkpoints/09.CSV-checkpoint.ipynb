# %%
data <- read.csv("CASchools.csv")
print(data)
# Out:
#       X district                                  school          county grades
# 1     1    75119                      Sunol Glen Unified         Alameda  KK-08
# 2     2    61499                    Manzanita Elementary           Butte  KK-08
# 3     3    61549             Thermalito Union Elementary           Butte  KK-08
# 4     4    61457         Golden Feather Union Elementary           Butte  KK-08
# 5     5    61523                Palermo Union Elementary           Butte  KK-08
# 6     6    62042                 Burrel Union Elementary          Fresno  KK-08
# 7     7    68536                   Holt Union Elementary     San Joaquin  KK-08
# 8     8    63834                     Vineland Elementary            Kern  KK-08
# 9     9    62331                Orange Center Elementary          Fresno  KK-08
# 10   10    67306             Del Paso Heights Elementary      Sacramento  KK-06
# 11   11    65722               Le Grand Union Elementary          Merced  KK-08
# ...

# %%
print(is.data.frame(data))
# Out:
# [1] TRUE

# %%
print(ncol(data))
# Out:
# [1] 15

# %%
print(nrow(data))
# Out:
# [1] 420

# %%
math <- max(data$math)
print(math)
# Out:
# [1] 709.5

# %%
retval <- subset(data, math == max(math))
print(retval)
# Out:
#       X district               school      county grades students teachers
# 417 417    69518 Los Altos Elementary Santa Clara  KK-08     3724   208.48
#     calworks  lunch computer expenditure   income  english read  math
# 417   1.0741 1.5038      721    5741.463 41.73411 4.726101  704 709.5

# %%
retval <- subset( data, county == "Kern")
print(retval)
# Out:
#       X district                              school county grades students
# 8     8    63834                 Vineland Elementary   Kern  KK-08      888
# 17   17    63594         Lost Hills Union Elementary   Kern  KK-08      491
# 18   18    63370       Buttonwillow Union Elementary   Kern  KK-08      421
# 20   20    63560                   Lamont Elementary   Kern  KK-08     2688
# 23   23    63842              Wasco Union Elementary   Kern  KK-08     2538
# 28   28    63313              Arvin Union Elementary   Kern  KK-08     2601
# 40   40    63578     Richland-Lerdo Union Elementary   Kern  KK-08     2471
# 43   43    63461                  Fairfax Elementary   Kern  KK-08     1217
# 44   44    63404             Delano Union Elementary   Kern  KK-08     6219
# 48   48    63438                   Edison Elementary   Kern  KK-08      814
# 49   49    63321         Bakersfield City Elementary   Kern  KK-08    27176
# ...

# %%
info <- subset(data, math> 600 & county== "Kern")
print(info)
# Out:
#       X district                              school county grades students
# 8     8    63834                 Vineland Elementary   Kern  KK-08      888
# 17   17    63594         Lost Hills Union Elementary   Kern  KK-08      491
# 18   18    63370       Buttonwillow Union Elementary   Kern  KK-08      421
# 20   20    63560                   Lamont Elementary   Kern  KK-08     2688
# 23   23    63842              Wasco Union Elementary   Kern  KK-08     2538
# 28   28    63313              Arvin Union Elementary   Kern  KK-08     2601
# 40   40    63578     Richland-Lerdo Union Elementary   Kern  KK-08     2471
# 43   43    63461                  Fairfax Elementary   Kern  KK-08     1217
# 44   44    63404             Delano Union Elementary   Kern  KK-08     6219
# 48   48    63438                   Edison Elementary   Kern  KK-08      814
# 49   49    63321         Bakersfield City Elementary   Kern  KK-08    27176
# ...

# %%
write.csv(retval,"outcsv.csv")
newdata <- read.csv("outcsv.csv")
print(newdata)
# Out:
#    X.1   X district                              school county grades students
# 1    8   8    63834                 Vineland Elementary   Kern  KK-08      888
# 2   17  17    63594         Lost Hills Union Elementary   Kern  KK-08      491
# 3   18  18    63370       Buttonwillow Union Elementary   Kern  KK-08      421
# 4   20  20    63560                   Lamont Elementary   Kern  KK-08     2688
# 5   23  23    63842              Wasco Union Elementary   Kern  KK-08     2538
# 6   28  28    63313              Arvin Union Elementary   Kern  KK-08     2601
# 7   40  40    63578     Richland-Lerdo Union Elementary   Kern  KK-08     2471
# 8   43  43    63461                  Fairfax Elementary   Kern  KK-08     1217
# 9   44  44    63404             Delano Union Elementary   Kern  KK-08     6219
# 10  48  48    63438                   Edison Elementary   Kern  KK-08      814
# 11  49  49    63321         Bakersfield City Elementary   Kern  KK-08    27176
# ...
